# %%
import pandas as pd

data = pd.read_csv("Prices.csv")

# %%
data = pd.DataFrame(data)
data
# Out:
#     TexmacoRail  CentralBank  KothariSugar    PCBL  GreavesCotton  \
# 0        136.45        37.60          55.6  161.20          138.1
# 1        136.45        37.60          55.6  161.30          138.1
# 2        136.45        37.60          55.6  161.30          138.1
# 3        136.45        37.60          55.6  161.30          138.1
# 4        137.70        38.25          55.6  161.30          140.8
# 5        137.70        38.25          55.6  164.40          140.8
# 6        137.70        38.25          55.6  164.40          140.8
# 7        137.70        38.25          55.6  164.40          140.8
# 8        141.95        38.25          55.6  164.40          140.8
# 9        141.95        38.25          53.1  164.40          140.8
# 10       133.15        38.00          55.0  164.25          139.7
#
#     PadamjiPaper                        Time
# 0          47.75  2023-09-13 09:11:41.093625
# 1          48.70  2023-09-13 09:17:55.361090
# ...
